# %%
# TreeExplainer 
# run in same session after supervised learning
# see epiPred_STXBP1.ipynb for that code

import shap

# check which version of shap
## 0.39.0  ## latest is approx 0.43.0
print(shap.__version__)

# print the JS visualization code to the notebook
shap.initjs()

# based on this https://github.com/shap/shap/issues/14

explainer = shap.TreeExplainer(clf)
shap_values = explainer(X)
# Out:
# 0.39.0
# ...

# %%
 ## full dataset

dfs_noclass = dfs.drop(['CLASS'], axis=1)

df_tmp = pd.DataFrame(dfs_noclass)
feature_names=df_tmp.columns

explainer = shap.TreeExplainer(clf)

shap_values = explainer(df_tmp)

tmp = shap.Explanation(shap_values[:, :, 1], data=df_tmp, feature_names=feature_names)

# %%
# Beeswarm plots
## global explanations
shap.plots.beeswarm(tmp, plot_size = (20,7),show=True)
shap.plots.beeswarm(tmp, plot_size = (20,7),show=False)

# save image
plt.savefig('/projects/b1073/u54/jdc_sandbox/newRun_31jul2024/global_explanation/shap_featureBeeswarm_fullDataset_RF_160est_5dep_5aug2024_20x7.svg', format="svg")
plt.close()

# %%
# example decision plot
shap.decision_plot(tmp.base_values[0], tmp.values, feature_names, ignore_warnings=True)
